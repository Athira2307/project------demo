# %% [markdown]
#  Importing the libraries

# %%
### Data Wrangling

import numpy as np
import pandas as pd


### Data Visualization

import matplotlib.pyplot as plt
import seaborn as sns


### Remove unnecessary warnings

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
#  Importing the data

# %%
### Fetching the dataset

data = pd.read_csv('train1.csv',low_memory=False)

# %%
### Looking at the sample data in the dataset

data.head()
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
# 3  0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265  Scientist
# 4  0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
# 3      19114.12                    NaN                  3  ...        Good
# 4      19114.12            1824.843333                  3  ...        Good
#
# ...

# %% [markdown]
# ### Dataset description
#
# ID: Represents a unique identification of an entry
#
# Customer_ID: Represents a unique identification of a person
#
# Month: Represents the month of the year
#
# Name: Represents the name of a person
#
# Age: Represents the age of the person
#
# SSN: Represents the social security number of a person
#
# Occupation: Represents the occupation of the person
#
# Annual_Income: Represents the annual income of the person
#
# Monthly_Inhand_Salary: Represents the monthly base salary of a person
#
# Num_Bank_Accounts: Represents the number of bank accounts a person holds
#
# Num_Credit_Card: Represents the number of other credit cards held by a person
#
# Interest_Rate: Represents the interest rate on credit card
#
# Num_of_Loan: Represents the number of loans taken from the bank
#
# Type_of_Loan: Represents the types of loan taken by a person
#
# Delay_from_due_date: Represents the average number of days delayed from the payment date
#
# Num_of_delayed_Payment: Represents the average number of payments delayed by a person
#
# Changed_Credit_Limit: Represents the percentage change in credit card limit
#
# Num_Credit_Inquiries: Represents the number of credit card inquiries
#
# Credit_Mix: Represents the classification of the mix of credits
#
# Outstanding_Debt: Represents the remaining debt to be paid (in USD)
#
# Credit_Utilization_Ratio: Represents the utilization ratio of credit card
#
# Credit_History_Age: Represents the age of credit history of the person
#
# Payment_of_Min_Amount: Represents whether only the minimum amount was paid by the person
#
# Total_EMI_per_Month : Represents the monthly EMI amount paid by the person
#
# Amount_invested_monthly: Represents the monthly amount invested by the customer (in USD)
#
# Payment_Behaviour: Represents the payment behavior of the customer (in USD)
#
# Monthly_Balance: Represents the monthly balance amount of the customer (in USD)
#
# Credit_Score: Represents the bracket of credit score (Poor, Standard, Good)

# %%
### Shape of the dataset

data.shape
# Out:
# (100000, 28)

# %% [markdown]
# The dataset consists of 28 columns and 100000 rows.

# %%
### Re-size the dataset

data = data[:8000]

# %%
### Shape of the dataset

data.shape
# Out:
# (8000, 28)

# %%
### Summary statistics of the numerical columns in the dataset

data.describe()
# Out:
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# count            6823.000000        8000.000000      8000.000000
# mean             4299.166681          17.031125        24.076750
# std              3202.084855         119.001557       138.319615
# min               355.208333           0.000000         0.000000
# 25%              1698.773333           3.000000         4.000000
# 50%              3211.081667           6.000000         5.000000
# 75%              5978.466667           8.000000         7.000000
# max             14828.983333        1777.000000      1486.000000
#
#        Interest_Rate  Delay_from_due_date  Num_Credit_Inquiries  \
# count    8000.000000          8000.000000           7841.000000
# mean       73.933875            21.642625             23.061599
# std       466.972928            14.749478            166.795965
# min         1.000000            -5.000000              0.000000
# ...

# %%
### Looking at the datatypes of the data

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        8000 non-null   object
#  1   Customer_ID               8000 non-null   object
#  2   Month                     8000 non-null   object
#  3   Name                      7207 non-null   object
#  4   Age                       8000 non-null   object
#  5   SSN                       8000 non-null   object
#  6   Occupation                8000 non-null   object
#  7   Annual_Income             8000 non-null   object
#  8   Monthly_Inhand_Salary     6823 non-null   float64
#  9   Num_Bank_Accounts         8000 non-null   int64
#  10  Num_Credit_Card           8000 non-null   int64
#  11  Interest_Rate             8000 non-null   int64
#  12  Num_of_Loan               8000 non-null   object
# ...

# %% [markdown]
# From the above data, the columns - Month, Occupation, Type_of_Loan, Credit_Mix, Payment_of_Min_Amount, Payment_Behaviour, Credit_Score are categorical. Hence, we will modify the datatypes of these columns to category.
#
#
# From the above data,the columns - Age, Annual_Income, Num_of_Loan, Num_of_Delayed_Payment, Changed_Credit_Limit, Outstanding_Debt, Amount_invested_monthly, Monthly_Balance are object data type so we will change the datatype of these columns from object to a numerical datatype like int or float.

# %%
### Changing the datatype of the above mentioned columns to category

for i in [ 'Month', 'Occupation', 'Type_of_Loan', 'Credit_Mix', 'Payment_of_Min_Amount', 'Payment_Behaviour', 'Credit_Score'] :     
     data[i]= data[i].astype('category')

# %% [markdown]
# ### Removing symbols/characters present in rows

# %%
data.columns
# Out:
# Index(['ID', 'Customer_ID', 'Month', 'Name', 'Age', 'SSN', 'Occupation',
#        'Annual_Income', 'Monthly_Inhand_Salary', 'Num_Bank_Accounts',
#        'Num_Credit_Card', 'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan',
#        'Delay_from_due_date', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit',
#        'Num_Credit_Inquiries', 'Credit_Mix', 'Outstanding_Debt',
#        'Credit_Utilization_Ratio', 'Credit_History_Age',
#        'Payment_of_Min_Amount', 'Total_EMI_per_month',
#        'Amount_invested_monthly', 'Payment_Behaviour', 'Monthly_Balance',
#        'Credit_Score'],
#       dtype='object')

# %%
# check unique values in all columns

for col in data.columns:
     print(f"\n{col}\n",data[col].unique(), '\n', '--'*40, '\n')
# Out:
# ID
#  ['0x1602' '0x1603' '0x1604' ... '0x44db' '0x44dc' '0x44dd']
#  --------------------------------------------------------------------------------
#
#
# Customer_ID
#  ['CUS_0xd40' 'CUS_0x21b1' 'CUS_0x2dbc' 'CUS_0xb891' 'CUS_0x1cdb'
#  'CUS_0x95ee' 'CUS_0x284a' 'CUS_0x5407' 'CUS_0x4157' 'CUS_0xba08'
#  'CUS_0xa66b' 'CUS_0xc0ab' 'CUS_0x3e45' 'CUS_0x6c66' 'CUS_0xff4'
#  'CUS_0x33d2' 'CUS_0x6070' 'CUS_0xfdb' 'CUS_0x3553' 'CUS_0x4100'
#  'CUS_0x132f' 'CUS_0xa16e' 'CUS_0xac86' 'CUS_0x5b48' 'CUS_0xa5f9'
#  'CUS_0x4d43' 'CUS_0xb95f' 'CUS_0x3edc' 'CUS_0xbffe' 'CUS_0xb681'
#  'CUS_0x9a71' 'CUS_0x6048' 'CUS_0x95b5' 'CUS_0x4004' 'CUS_0xb101'
#  'CUS_0x9b94' 'CUS_0x4080' 'CUS_0x706a' 'CUS_0x42ac' 'CUS_0x571f'
#  'CUS_0xb5ff' 'CUS_0x6a1b' 'CUS_0x9bc1' 'CUS_0xc65' 'CUS_0xaedb'
#  'CUS_0x8e9b' 'CUS_0x609d' 'CUS_0x75c6' 'CUS_0x9b3c' 'CUS_0x22a3'
#  'CUS_0xb14' 'CUS_0xb986' 'CUS_0xbe1b' 'CUS_0x9ce6' 'CUS_0x6ffb'
#  'CUS_0x4315' 'CUS_0x3f5b' 'CUS_0x9d78' 'CUS_0x47db' 'CUS_0x8f17'
# ...

# %%
convert_cols = [ 'Age', 'Annual_Income', 'Num_of_Loan', 'Num_of_Delayed_Payment', 'Changed_Credit_Limit', 'Outstanding_Debt', 'Amount_invested_monthly', 'Monthly_Balance']

# %%
### Remove unwanted characters from the selected columns using for loop
    # Removes - and _ from beginning and end of values

for col in convert_cols:  
    data[col] = data[col].str.strip('-_')

# %%
### Replace empty row with nan to whole dataframe

data.replace('', np.NaN, inplace=True) 
data.replace('_______', np.NaN, inplace=True)

# %%
### Replace error value with nan

data['Payment_Behaviour'] = data['Payment_Behaviour'].replace('!@9#%8', np.nan)

# %%
### Check unique values in all columns

for col in data.columns:
    print(f"\n{col}\n",data[col].unique() ,'\n', '--'*60, '\n')
# Out:
# ID
#  ['0x1602' '0x1603' '0x1604' ... '0x44db' '0x44dc' '0x44dd']
#  ------------------------------------------------------------------------------------------------------------------------
#
#
# Customer_ID
#  ['CUS_0xd40' 'CUS_0x21b1' 'CUS_0x2dbc' 'CUS_0xb891' 'CUS_0x1cdb'
#  'CUS_0x95ee' 'CUS_0x284a' 'CUS_0x5407' 'CUS_0x4157' 'CUS_0xba08'
#  'CUS_0xa66b' 'CUS_0xc0ab' 'CUS_0x3e45' 'CUS_0x6c66' 'CUS_0xff4'
#  'CUS_0x33d2' 'CUS_0x6070' 'CUS_0xfdb' 'CUS_0x3553' 'CUS_0x4100'
#  'CUS_0x132f' 'CUS_0xa16e' 'CUS_0xac86' 'CUS_0x5b48' 'CUS_0xa5f9'
#  'CUS_0x4d43' 'CUS_0xb95f' 'CUS_0x3edc' 'CUS_0xbffe' 'CUS_0xb681'
#  'CUS_0x9a71' 'CUS_0x6048' 'CUS_0x95b5' 'CUS_0x4004' 'CUS_0xb101'
#  'CUS_0x9b94' 'CUS_0x4080' 'CUS_0x706a' 'CUS_0x42ac' 'CUS_0x571f'
#  'CUS_0xb5ff' 'CUS_0x6a1b' 'CUS_0x9bc1' 'CUS_0xc65' 'CUS_0xaedb'
#  'CUS_0x8e9b' 'CUS_0x609d' 'CUS_0x75c6' 'CUS_0x9b3c' 'CUS_0x22a3'
#  'CUS_0xb14' 'CUS_0xb986' 'CUS_0xbe1b' 'CUS_0x9ce6' 'CUS_0x6ffb'
# ...

# %%
### Changing the datatype of the above mentioned columns to int or float


for j in convert_cols :     
     data[j]= data[j].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID                        8000 non-null   object
#  1   Customer_ID               8000 non-null   object
#  2   Month                     8000 non-null   category
#  3   Name                      7207 non-null   object
#  4   Age                       8000 non-null   float64
#  5   SSN                       8000 non-null   object
#  6   Occupation                7437 non-null   category
#  7   Annual_Income             8000 non-null   float64
#  8   Monthly_Inhand_Salary     6823 non-null   float64
#  9   Num_Bank_Accounts         8000 non-null   int64
#  10  Num_Credit_Card           8000 non-null   int64
#  11  Interest_Rate             8000 non-null   int64
#  12  Num_of_Loan               8000 non-null   float64
# ...

# %%
data.nunique().sort_values(ascending = False)
# Out:
# ID                          8000
# Credit_Utilization_Ratio    8000
# Monthly_Balance             7895
# Amount_invested_monthly     7308
# Changed_Credit_Limit        1614
# Total_EMI_per_month         1190
# Annual_Income               1074
# Monthly_Inhand_Salary       1053
# SSN                         1001
# Customer_ID                 1000
# Outstanding_Debt             998
# Name                         980
# Type_of_Loan                 673
# Credit_History_Age           404
# Age                          216
# Interest_Rate                205
# Num_Credit_Card              183
# Num_Credit_Inquiries         128
# Num_Bank_Accounts            107
# Num_of_Delayed_Payment        89
# Delay_from_due_date           73
# Num_of_Loan                   51
# Occupation                    15
# Month                          8
# Payment_Behaviour              6
# Credit_Mix                     4
# Payment_of_Min_Amount          3
# Credit_Score                   3
# dtype: int64

# %%
data.isna().sum().sort_values(ascending = False)
# Out:
# Monthly_Inhand_Salary       1177
# Type_of_Loan                 952
# Name                         793
# Credit_History_Age           741
# Payment_Behaviour            636
# Occupation                   563
# Num_of_Delayed_Payment       560
# Amount_invested_monthly      337
# Changed_Credit_Limit         165
# Num_Credit_Inquiries         159
# Monthly_Balance              105
# Payment_of_Min_Amount          0
# Credit_Utilization_Ratio       0
# Outstanding_Debt               0
# Total_EMI_per_month            0
# Credit_Mix                     0
# ID                             0
# Delay_from_due_date            0
# Customer_ID                    0
# Num_of_Loan                    0
# Interest_Rate                  0
# Num_Credit_Card                0
# Num_Bank_Accounts              0
# Annual_Income                  0
# SSN                            0
# Age                            0
# Month                          0
# Credit_Score                   0
# dtype: int64

# %%
### DROP THE UNNECESSARY COLUMNS.

data1 = data.drop(['ID','Customer_ID','Name','SSN'], axis=1)

# %%
data1.isna().sum().sort_values(ascending = False)
# Out:
# Monthly_Inhand_Salary       1177
# Type_of_Loan                 952
# Credit_History_Age           741
# Payment_Behaviour            636
# Occupation                   563
# Num_of_Delayed_Payment       560
# Amount_invested_monthly      337
# Changed_Credit_Limit         165
# Num_Credit_Inquiries         159
# Monthly_Balance              105
# Outstanding_Debt               0
# Total_EMI_per_month            0
# Payment_of_Min_Amount          0
# Credit_Utilization_Ratio       0
# Month                          0
# Credit_Mix                     0
# Age                            0
# Delay_from_due_date            0
# Num_of_Loan                    0
# Interest_Rate                  0
# Num_Credit_Card                0
# Num_Bank_Accounts              0
# Annual_Income                  0
# Credit_Score                   0
# dtype: int64

# %% [markdown]
# ### DATA VISUALIZATION

# %% [markdown]
# ###### Univariate Analysis

# %%
### Value counts of the column - Occupation

occupation_count = data['Occupation'].value_counts(dropna = False)
occupation_count
# Out:
# Journalist       592
# NaN              563
# Lawyer           553
# Writer           538
# Entrepreneur     536
# Musician         528
# Media_Manager    527
# Doctor           521
# Mechanic         509
# Architect        506
# Scientist        489
# Teacher          448
# Manager          440
# Accountant       430
# Engineer         423
# Developer        397
# Name: Occupation, dtype: int64

# %%
### Bar graph showing the value counts of the column - Occupation

plt.figure(figsize=(20,10))
sns.barplot(occupation_count.index, occupation_count.values)
plt.title('Bar graph showing the value counts of the column - Occupation')
plt.ylabel('Count', fontsize = 12)
plt.xlabel('Occupation', fontsize = 12)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the above graph, we can see that most of the jobs are Journalist.

# %%
### Value counts of the column - Credit_Mix

credit_mix_count = data['Credit_Mix'].value_counts(dropna = False)
credit_mix_count
# Out:
# Standard    2832
# Good        2000
# _           1616
# Bad         1552
# Name: Credit_Mix, dtype: int64

# %%
### Bar graph showing the value counts of the column - Credit_Mix

plt.figure(figsize=(10,5))
sns.barplot(credit_mix_count.index, credit_mix_count.values, alpha = 0.8)
plt.title('Bar graph showing the value counts of the column - Credit_Mix')
plt.ylabel('Number of Occurrences', fontsize = 12)
plt.xlabel('Credit Mix', fontsize = 12)
plt.show()

# %% [markdown]
# From the above graph, we can see that most of the customers have a 'Standard' credit mix.

# %%
### Value counts of the column - Payment_of_Min_Amount

min_amount_count = data['Payment_of_Min_Amount'].value_counts(dropna = False)
min_amount_count
# Out:
# Yes    4176
# No     2856
# NM      968
# Name: Payment_of_Min_Amount, dtype: int64

# %%
### Bar graph showing the value counts of the column - Payment_of_Min_Amount

plt.figure(figsize=(10,5))
sns.barplot(min_amount_count.index, min_amount_count.values, alpha = 0.8)
plt.title('Bar graph showing the value counts of the column - Payment_of_Min_Amount')
plt.ylabel('Number of Occurrences', fontsize = 12)
plt.xlabel('Payment of Minimum Amount', fontsize = 12)
plt.show()

# %% [markdown]
# From the above graph, we can see that most of the customer's paid a minimum amount for their loans.

# %%
### Value counts of the column - Payment_Behaviour

payment = data['Payment_Behaviour'].value_counts(dropna=False)
payment
# Out:
# Low_spent_Small_value_payments      1987
# High_spent_Medium_value_payments    1439
# Low_spent_Medium_value_payments     1116
# High_spent_Large_value_payments     1099
# High_spent_Small_value_payments      902
# Low_spent_Large_value_payments       821
# NaN                                  636
# Name: Payment_Behaviour, dtype: int64

# %%
### Bar graph showing the value counts of the column - Payment_Behaviour

plt.figure(figsize=(10,5))
sns.barplot(payment.index, payment.values, alpha = 0.8)
plt.title('Bar graph showing the value counts of the column - Payment_Behaviour')
plt.ylabel('Number of Occurrences', fontsize = 12)
plt.xlabel('Payment Behaviour', fontsize = 12)
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# From the above graph, we can see that most of the customers payment behaviour is Low_spent_Small_value_payments.

# %% [markdown]
# ###### Bivariate Analysis

# %%
### Distribution of Credit_Score for each Occupation

sns.factorplot('Credit_Score', col = 'Occupation', data = data, kind = 'count', col_wrap = 4)
plt.show()

# %% [markdown]
# From the above graphs, we can see that most of the people have a Credit Score in the Standard range for all the Occupations.

# %%
### Distribution of Credit_Score for each Credit_Mix


sns.factorplot('Credit_Score', col = 'Credit_Mix', data = data, kind = 'count', col_wrap = 4)

# %% [markdown]
# From the above graphs, we can see that the columns - Credit_Mix and Credit_Score are almost similar.

# %%
### Distribution of Payment_of_Min_Amount for each Credit Score

sns.factorplot('Payment_of_Min_Amount', col = 'Credit_Score', data = data, kind = 'count', col_wrap = 3)

# %% [markdown]
# From the above graphs, we can see that the most of the customers with a good credit score didn't pay the minimum amount for the loan. Similarly, customers with a poor credit score paid the minimum amount for the loan.
